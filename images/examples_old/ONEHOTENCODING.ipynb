# %%
import xcast as xc 
import xarray as xr 
import cartopy.crs as ccrs 

obs = xr.open_dataset('data/OBS_JJA.nc').precip.expand_dims({'M':[0]})

# %%
obs
# Out:
# <xarray.DataArray 'precip' (M: 1, time: 24, latitude: 400, longitude: 1440)>
# array([[[[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          ...,
# ...
#          ...,
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
ohe = xc.OneHotEncoder()
ohe.fit(obs)
T = ohe.transform(obs)

# %%
T
# Out:
# <xarray.DataArray 'precip' (M: 3, time: 24, latitude: 400, longitude: 1440)>
# dask.array<mul, shape=(3, 24, 400, 1440), dtype=float32, chunksize=(1, 24, 400, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * M          (M) <U2 'BN' 'NN' 'AN'
#   * time       (time) datetime64[ns] 1993-05-01 1994-05-01 ... 2016-05-01
#   * latitude   (latitude) float32 -49.88 -49.62 -49.38 ... 49.38 49.62 49.88
#   * longitude  (longitude) float32 -179.9 -179.6 -179.4 ... 179.4 179.6 179.9
# Attributes:
#     generated_by:  \n  XCAST Ranked Tercile One-Hot Encoded
